# %% [markdown]
# # Data exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = None

# %matplotlib inline

# %%
data = pd.read_excel('../data/portfolio.xlsx')
data.head()
# Out:
#   Installation Date  Installation Number  Client Type    Panel  \
# 0        2015-01-02              1833069  Normal       SDVFAST
# 1        2015-01-02              1833074  Normal       SDVFAST
# 2        2015-01-02              1833079  Normal       SDVFAST
# 3        2015-01-02              1833080  Normal       SDVFAST
# 4        2015-01-02              1833081  Normal       SDVFAST
#
#        Territorial        Provincia    Zip      Gender    Nationality  \
# 0              Sur          Granada  18198  H - HOMBRE  ES - ESPAÑOLA
# 1          Noreste        Barcelona  08173   M - MUJER  ES - ESPAÑOLA
# 2  Centro-Noroeste  Madrid Noroeste  28011  H - HOMBRE  ES - ESPAÑOLA
# 3              Sur          Sevilla  41500   M - MUJER  ES - ESPAÑOLA
# 4          Noreste        Barcelona  08014  H - HOMBRE  ES - ESPAÑOLA
#
#   Country Of Birth  Born Date                Housing Type     Labor Situation  \
# 0            SPAIN 1959-09-02    2 - PROPIEDAD HIPOTECADA      03 FUNCIONARIO
# 1            SPAIN 1971-04-15       4 - FAMILIARES/PADRES           06 PARADO
# 2            SPAIN 1968-02-10  1 - PROPIEDAD SIN HIPOTECA  01 ASALARIADO FIJO
# 3            SPAIN 1968-12-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
# 4            SPAIN 1977-02-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
#
#             Marital Status  Income Amount  Number Pay Price List  \
# 0               2 - CASADO           2000          13      EED
# 1  4 - SEPARADO/DIVORCIADO            600          12      EED
# 2  4 - SEPARADO/DIVORCIADO           2500          14      HBD
# 3               2 - CASADO           1800          12      EED
# 4               2 - CASADO           1500          12      EEE
#
#    Account Balance Monitoring Status Date Monitoring Status  Precio Contado  \
# 0              0.0             2019-06-30              BAJA             435
# 1              0.0             2015-01-05              OP               494
# 2              0.0             2015-01-05              OP               554
# 3              0.0             2015-01-13              OP               494
# 4              0.0             2015-01-07              OP               554
#
#    Precio Financiado  Quejas
# 0              360.0     NaN
# 1              360.0    12.0
# 2                0.0     NaN
# 3                0.0     2.0
# 4              360.0     NaN

# %%
data.shape
# Out:
# (490659, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490659 entries, 0 to 490658
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Installation Date       490659 non-null  datetime64[ns]
#  1   Installation Number     490659 non-null  int64
#  2   Client Type             490659 non-null  object
#  3   Panel                   490659 non-null  object
#  4   Territorial             490659 non-null  object
#  5   Provincia               490659 non-null  object
#  6   Zip                     490659 non-null  object
#  7   Gender                  490659 non-null  object
#  8   Nationality             490659 non-null  object
#  9   Country Of Birth        490659 non-null  object
#  10  Born Date               488665 non-null  datetime64[ns]
#  11  Housing Type            490659 non-null  object
#  12  Labor Situation         490659 non-null  object
#  13  Marital Status          490659 non-null  object
#  14  Income Amount           490659 non-null  int64
#  15  Number Pay              490659 non-null  int64
#  16  Price List              490659 non-null  object
#  17  Account Balance         490659 non-null  float64
#  18  Monitoring Status Date  490659 non-null  datetime64[ns]
#  19  Monitoring Status       490659 non-null  object
#  20  Precio Contado          490659 non-null  int64
#  21  Precio Financiado       490659 non-null  float64
#  22  Quejas                  83279 non-null   float64
# dtypes: datetime64[ns](3), float64(3), int64(4), object(13)
# memory usage: 86.1+ MB

# %%
data.isnull().sum()
# Out:
# Installation Date              0
# Installation Number            0
# Client Type                    0
# Panel                          0
# Territorial                    0
# Provincia                      0
# Zip                            0
# Gender                         0
# Nationality                    0
# Country Of Birth               0
# Born Date                   1994
# Housing Type                   0
# Labor Situation                0
# Marital Status                 0
# Income Amount                  0
# Number Pay                     0
# Price List                     0
# Account Balance                0
# Monitoring Status Date         0
# Monitoring Status              0
# Precio Contado                 0
# Precio Financiado              0
# Quejas                    407380
# dtype: int64

# %%
def dataoveriew(df, message):
    print(f'{message}:\n')
    print("Número de Filas:", df.shape[0])
    print("\nNúmero de Columnas:", df.shape[1])
    print("\nColumnas:\n")
    print(data.columns.tolist())
    print("\nValores nulos:", df.isnull().sum().values.sum())
    print("\nValores únicos:\n")
    print(df.nunique())

# %%
dataoveriew(data, 'Overiew of the dataset')
# Out:
# Overiew of the dataset:
#
# Número de Filas: 490659
#
# Número de Columnas: 23
#
# Columnas:
#
# ['Installation Date', 'Installation Number', 'Client Type', 'Panel', 'Territorial', 'Provincia', 'Zip', 'Gender', 'Nationality', 'Country Of Birth', 'Born Date', 'Housing Type', 'Labor Situation', 'Marital Status', 'Income Amount', 'Number Pay', 'Price List', 'Account Balance', 'Monitoring Status Date', 'Monitoring Status', 'Precio Contado', 'Precio Financiado', 'Quejas']
#
# Valores nulos: 409374
#
# Valores únicos:
#
# Installation Date           2201
# Installation Number       490574
# Client Type                    2
# Panel                          2
# Territorial                    7
# Provincia                     54
# Zip                         9210
# Gender                         2
# Nationality                   11
# Country Of Birth             195
# Born Date                  28028
# Housing Type                   6
# Labor Situation                8
# Marital Status                 6
# Income Amount               1819
# Number Pay                     5
# Price List                    28
# Account Balance            16283
# Monitoring Status Date      2037
# Monitoring Status              2
# Precio Contado              2331
# Precio Financiado            437
# Quejas                        33
# dtype: int64

# %%
data['Quejas'] = data['Quejas'].replace(np.nan, 0).astype('int')
data['Installation Number'] = data['Installation Number'].astype('str')
data.head()
# Out:
#   Installation Date Installation Number  Client Type    Panel  \
# 0        2015-01-02             1833069  Normal       SDVFAST
# 1        2015-01-02             1833074  Normal       SDVFAST
# 2        2015-01-02             1833079  Normal       SDVFAST
# 3        2015-01-02             1833080  Normal       SDVFAST
# 4        2015-01-02             1833081  Normal       SDVFAST
#
#        Territorial        Provincia    Zip      Gender    Nationality  \
# 0              Sur          Granada  18198  H - HOMBRE  ES - ESPAÑOLA
# 1          Noreste        Barcelona  08173   M - MUJER  ES - ESPAÑOLA
# 2  Centro-Noroeste  Madrid Noroeste  28011  H - HOMBRE  ES - ESPAÑOLA
# 3              Sur          Sevilla  41500   M - MUJER  ES - ESPAÑOLA
# 4          Noreste        Barcelona  08014  H - HOMBRE  ES - ESPAÑOLA
#
#   Country Of Birth  Born Date                Housing Type     Labor Situation  \
# 0            SPAIN 1959-09-02    2 - PROPIEDAD HIPOTECADA      03 FUNCIONARIO
# 1            SPAIN 1971-04-15       4 - FAMILIARES/PADRES           06 PARADO
# 2            SPAIN 1968-02-10  1 - PROPIEDAD SIN HIPOTECA  01 ASALARIADO FIJO
# 3            SPAIN 1968-12-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
# 4            SPAIN 1977-02-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
#
#             Marital Status  Income Amount  Number Pay Price List  \
# 0               2 - CASADO           2000          13      EED
# 1  4 - SEPARADO/DIVORCIADO            600          12      EED
# 2  4 - SEPARADO/DIVORCIADO           2500          14      HBD
# 3               2 - CASADO           1800          12      EED
# 4               2 - CASADO           1500          12      EEE
#
#    Account Balance Monitoring Status Date Monitoring Status  Precio Contado  \
# 0              0.0             2019-06-30              BAJA             435
# 1              0.0             2015-01-05              OP               494
# 2              0.0             2015-01-05              OP               554
# 3              0.0             2015-01-13              OP               494
# 4              0.0             2015-01-07              OP               554
#
#    Precio Financiado  Quejas
# 0              360.0       0
# 1              360.0      12
# 2                0.0       0
# 3                0.0       2
# 4              360.0       0

# %%
data.describe()
# Out:
#        Income Amount     Number Pay  Account Balance  Precio Contado  \
# count   4.906590e+05  490659.000000    490659.000000   490659.000000
# mean    2.307795e+04      13.045015       190.162936      618.273351
# std     4.400135e+06       1.081845       178.073064      362.511403
# min     0.000000e+00      12.000000     -1691.580000        4.000000
# 25%     1.200000e+03      12.000000         0.000000      494.000000
# 50%     1.500000e+03      13.000000       181.500000      554.000000
# 75%     2.000000e+03      14.000000       350.900000      675.000000
# max     1.600000e+09      16.000000      8727.990000   101707.000000
#
#        Precio Financiado         Quejas
# count      490659.000000  490659.000000
# mean          171.703884       0.299571
# std           223.711100       0.905683
# min             0.000000       0.000000
# 25%             0.000000       0.000000
# 50%             0.000000       0.000000
# 75%           360.000000       0.000000
# max         18790.000000      46.000000

# %%
# Don´t do this!!!!

# sns.pairplot(data = data, diag_kind = 'kde', hue = 'Monitoring Status');

# %%
sns.histplot(data = data, x="Quejas", hue = 'Monitoring Status', binwidth=1,  binrange = (0,5));

# %% [markdown]
# ### Totales y % de Baja en variables categóricas
#
# 'Client Type', 'Panel', 'Territorial', 'Provincia', 'Zip', 'Gender', 'Nationality', 'Country Of Birth', 'Housing Type', 'Labor Situation', 'Marital Status', 'Number Pay'

# %%
tab1 = pd.crosstab(data["Nationality"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Nationality"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status          BAJA    OP       All      BAJA      OP
# Nationality
# AF - AFRICA MENOS MAGREB     48     284     332  0.144578  0.855422
# AJ - AUSTRALIA Y JAPON        7      80      87  0.080460  0.919540
# AS - ASIA MENOS JAPON       264    1769    2033  0.129857  0.870143
# ES - ESPAÃOLA              173    9668    9841  0.017580  0.982420
# ES - ESPAÑOLA             45293  400269  445562  0.101654  0.898346
# IB - IBEROAMERICA           492    2976    3468  0.141869  0.858131
# MA - MAGREB                  61     364     425  0.143529  0.856471
# OT - OTROS                  429    2391    2820  0.152128  0.847872
# RE - RESTO DE EUROPA        201    2054    2255  0.089135  0.910865
# UE - UNION EUROPEA         2124   21317   23441  0.090610  0.909390
# US - USA / CANADA            25     370     395  0.063291  0.936709
# All                       49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Client Type"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Client Type"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status   BAJA    OP       All      BAJA      OP
# Client Type
# Gran_Cuenta         2106   18348   20454  0.102963  0.897037
# Normal             47011  423194  470205  0.099980  0.900020
# All                49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Panel"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Panel"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status   BAJA    OP       All      BAJA      OP
# Panel
# SDVFAST            48429  355220  403649  0.119978  0.880022
# SDVFSW               688   86322   87010  0.007907  0.992093
# All                49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Territorial"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Territorial"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status   BAJA    OP       All      BAJA      OP
# Territorial
# Centro-Noroeste     9574   74211   83785  0.114269  0.885731
# Centro-Norte        8244   64088   72332  0.113974  0.886026
# Centro-Sur          7066   59052   66118  0.106870  0.893130
# ErrorProvincia         2      10      12  0.166667  0.833333
# Este                7798   78516   86314  0.090345  0.909655
# Noreste             8224   92194  100418  0.081898  0.918102
# Sur                 8209   73471   81680  0.100502  0.899498
# All                49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Provincia"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Provincia"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status       0      1     All         0         1
# Provincia
# Alava                1198    218    1416  0.846045  0.153955
# Albacete             2665    361    3026  0.880701  0.119299
# Alicante            20372   1891   22263  0.915061  0.084939
# Almeria              6362    597    6959  0.914212  0.085788
# Asturias             6999    942    7941  0.881375  0.118625
# Avila                1104    109    1213  0.910140  0.089860
# Badajoz              5678    840    6518  0.871126  0.128874
# Baleares            20663   1312   21975  0.940296  0.059704
# Barcelona           67681   6133   73814  0.916913  0.083087
# Burgos               1610    259    1869  0.861423  0.138577
# Caceres              2548    412    2960  0.860811  0.139189
# Cadiz               10992   1301   12293  0.894167  0.105833
# Cantabria            3692    504    4196  0.879886  0.120114
# Castellon            5068    906    5974  0.848343  0.151657
# Ceuta                 480     45     525  0.914286  0.085714
# Ciudad Real          4668    767    5435  0.858878  0.141122
# Cordoba              5122    515    5637  0.908639  0.091361
# Cuenca               2245    304    2549  0.880738  0.119262
# ErrorProvincia         10      2      12  0.833333  0.166667
# Gerona               9830    735   10565  0.930431  0.069569
# Granada              6989    970    7959  0.878125  0.121875
# Guadalajara          4413    396    4809  0.917654  0.082346
# Guipuzcoa            3920    731    4651  0.842829  0.157171
# Huelva               6547    701    7248  0.903284  0.096716
# Huesca               1076    137    1213  0.887057  0.112943
# Jaen                 3620    457    4077  0.887908  0.112092
# La Coruña            5962   1028    6990  0.852933  0.147067
# Leon                 3070    494    3564  0.861392  0.138608
# Lerida               2609    369    2978  0.876091  0.123909
# Lugo                 1862    258    2120  0.878302  0.121698
# Madrid Noroeste     40262   4574   44836  0.897984  0.102016
# Madrid Norte        30806   3360   34166  0.901657  0.098343
# Malaga              17846   1654   19500  0.915179  0.084821
# Melilla               534     70     604  0.884106  0.115894
# Murcia              14707   1522   16229  0.906217  0.093783
# Navarra              2916    458    3374  0.864256  0.135744
# Orense               2173    338    2511  0.865392  0.134608
# Palencia              748    105     853  0.876905  0.123095
# Palmas              16514   1567   18081  0.913334  0.086666
# Pontevedra           5652    916    6568  0.860536  0.139464
# Rioja                1385    224    1609  0.860783  0.139217
# Salamanca            1904    239    2143  0.888474  0.111526
# Segovia              1443    163    1606  0.898506  0.101494
# Sevilla             14979   1899   16878  0.887487  0.112513
# Soria                 494     64     558  0.885305  0.114695
# Tarragona           12074    987   13061  0.924432  0.075568
# Tenerife            15889   1762   17651  0.900176  0.099824
# Teruel                569     78     647  0.879444  0.120556
# Toledo               8845   1053    9898  0.893615  0.106385
# Valencia            17706   2167   19873  0.890958  0.109042
# Valladolid           2872    369    3241  0.886146  0.113854
# Vizcaya              6497   1115    7612  0.853521  0.146479
# Zamora                908    144    1052  0.863118  0.136882
# Zaragoza             4764    595    5359  0.888972  0.111028
# All                441542  49117  490659  0.899896  0.100104

# %%
tab1 = pd.crosstab(data["Gender"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Gender"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status   BAJA    OP       All      BAJA      OP
# Gender
# H - HOMBRE         37456  342955  380411  0.098462  0.901538
# M - MUJER          11661   98587  110248  0.105771  0.894229
# All                49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Housing Type"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Housing Type"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status            BAJA    OP       All      BAJA      OP
# Housing Type
# 1 - PROPIEDAD SIN HIPOTECA  33070  343125  376195  0.087907  0.912093
# 2 - PROPIEDAD HIPOTECADA     9914   68645   78559  0.126198  0.873802
# 3 - ALQUILER                 4859   23222   28081  0.173035  0.826965
# 4 - FAMILIARES/PADRES         791    2867    3658  0.216238  0.783762
# 5 - EMPRESA                   482    3682    4164  0.115754  0.884246
# 6 - OTROS                       1       1       2  0.500000  0.500000
# All                         49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Labor Situation"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Labor Situation"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status                   BAJA    OP       All      BAJA      OP
# Labor Situation
# 01 ASALARIADO FIJO                 14237  170730  184967  0.076970  0.923030
# 02 ASALARIADO TEMPORAL               413    1834    2247  0.183801  0.816199
# 03 FUNCIONARIO                      1781   19029   20810  0.085584  0.914416
# 04 AUTONOMO                        24324  146670  170994  0.142251  0.857749
# 06 PARADO                           1171    4307    5478  0.213764  0.786236
# 07 PENSIONISTA (JUBILACION)         6245   92770   99015  0.063071  0.936929
# 08 PENSIONISTA (VIUDEDAD)            564    3533    4097  0.137662  0.862338
# 09 PENSIONISTA (LARGA ENFERMEDAD)    382    2669    3051  0.125205  0.874795
# All                                49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Marital Status"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Marital Status"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status         BAJA    OP       All      BAJA      OP
# Marital Status
# 1 - SOLTERO              13135   90311  103446  0.126974  0.873026
# 2 - CASADO               31104  306581  337685  0.092110  0.907890
# 3 - VIUDO                 2212   26150   28362  0.077992  0.922008
# 4 - SEPARADO/DIVORCIADO   2277   16076   18353  0.124067  0.875933
# 5 ? PAREJA DE HECHO        387    2384    2771  0.139661  0.860339
# 5 â PAREJA DE HECHO        2      40      42  0.047619  0.952381
# All                      49117  441542  490659  0.100104  0.899896

# %%
tab1 = pd.crosstab(data["Number Pay"], data["Monitoring Status"], margins = True)
tab2 = pd.crosstab(data["Number Pay"], data["Monitoring Status"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Monitoring Status   BAJA    OP       All      BAJA      OP
# Number Pay
# 12                 28613  212793  241406  0.118526  0.881474
# 13                  1021   11730   12751  0.080072  0.919928
# 14                 18235  199463  217698  0.083763  0.916237
# 15                   763    9854   10617  0.071866  0.928134
# 16                   485    7702    8187  0.059240  0.940760
# All                49117  441542  490659  0.100104  0.899896

# %% [markdown]
# ### Correlación

# %%
data['Monitoring Status'] = data['Monitoring Status'].astype('str').str.strip()
data['Monitoring Status'] = data['Monitoring Status'].replace({'OP': 0, 'BAJA': 1}).astype(int)
data.head()
# Out:
#   Installation Date Installation Number  Client Type    Panel  \
# 0        2015-01-02             1833069  Normal       SDVFAST
# 1        2015-01-02             1833074  Normal       SDVFAST
# 2        2015-01-02             1833079  Normal       SDVFAST
# 3        2015-01-02             1833080  Normal       SDVFAST
# 4        2015-01-02             1833081  Normal       SDVFAST
#
#        Territorial        Provincia    Zip      Gender    Nationality  \
# 0              Sur          Granada  18198  H - HOMBRE  ES - ESPAÑOLA
# 1          Noreste        Barcelona  08173   M - MUJER  ES - ESPAÑOLA
# 2  Centro-Noroeste  Madrid Noroeste  28011  H - HOMBRE  ES - ESPAÑOLA
# 3              Sur          Sevilla  41500   M - MUJER  ES - ESPAÑOLA
# 4          Noreste        Barcelona  08014  H - HOMBRE  ES - ESPAÑOLA
#
#   Country Of Birth  Born Date                Housing Type     Labor Situation  \
# 0            SPAIN 1959-09-02    2 - PROPIEDAD HIPOTECADA      03 FUNCIONARIO
# 1            SPAIN 1971-04-15       4 - FAMILIARES/PADRES           06 PARADO
# 2            SPAIN 1968-02-10  1 - PROPIEDAD SIN HIPOTECA  01 ASALARIADO FIJO
# 3            SPAIN 1968-12-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
# 4            SPAIN 1977-02-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
#
#             Marital Status  Income Amount  Number Pay Price List  \
# 0               2 - CASADO           2000          13      EED
# 1  4 - SEPARADO/DIVORCIADO            600          12      EED
# 2  4 - SEPARADO/DIVORCIADO           2500          14      HBD
# 3               2 - CASADO           1800          12      EED
# 4               2 - CASADO           1500          12      EEE
#
#    Account Balance Monitoring Status Date  Monitoring Status  Precio Contado  \
# 0              0.0             2019-06-30                  1             435
# 1              0.0             2015-01-05                  0             494
# 2              0.0             2015-01-05                  0             554
# 3              0.0             2015-01-13                  0             494
# 4              0.0             2015-01-07                  0             554
#
#    Precio Financiado  Quejas
# 0              360.0       0
# 1              360.0      12
# 2                0.0       0
# 3                0.0       2
# 4              360.0       0

# %%
corr = data.corr()
corr
# Out:
#                    Income Amount  Number Pay  Account Balance  \
# Income Amount           1.000000    0.006171         0.004920
# Number Pay              0.006171    1.000000         0.064352
# Account Balance         0.004920    0.064352         1.000000
# Monitoring Status      -0.000633   -0.060307        -0.246952
# Precio Contado          0.003762    0.000282         0.015423
# Precio Financiado       0.003970   -0.083397         0.152287
# Quejas                 -0.001094   -0.023394        -0.209647
#
#                    Monitoring Status  Precio Contado  Precio Financiado  \
# Income Amount              -0.000633        0.003762           0.003970
# Number Pay                 -0.060307        0.000282          -0.083397
# Account Balance            -0.246952        0.015423           0.152287
# Monitoring Status           1.000000       -0.021178           0.008359
# Precio Contado             -0.021178        1.000000           0.228147
# Precio Financiado           0.008359        0.228147           1.000000
# Quejas                      0.241228        0.010571          -0.016906
#
#                      Quejas
# Income Amount     -0.001094
# Number Pay        -0.023394
# Account Balance   -0.209647
# Monitoring Status  0.241228
# Precio Contado     0.010571
# Precio Financiado -0.016906
# Quejas             1.000000

# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(10, 220, as_cmap=True)
sns.heatmap(corr, annot=True, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
data.head()
# Out:
#   Installation Date Installation Number  Client Type    Panel  \
# 0        2015-01-02             1833069  Normal       SDVFAST
# 1        2015-01-02             1833074  Normal       SDVFAST
# 2        2015-01-02             1833079  Normal       SDVFAST
# 3        2015-01-02             1833080  Normal       SDVFAST
# 4        2015-01-02             1833081  Normal       SDVFAST
#
#        Territorial        Provincia    Zip      Gender    Nationality  \
# 0              Sur          Granada  18198  H - HOMBRE  ES - ESPAÑOLA
# 1          Noreste        Barcelona  08173   M - MUJER  ES - ESPAÑOLA
# 2  Centro-Noroeste  Madrid Noroeste  28011  H - HOMBRE  ES - ESPAÑOLA
# 3              Sur          Sevilla  41500   M - MUJER  ES - ESPAÑOLA
# 4          Noreste        Barcelona  08014  H - HOMBRE  ES - ESPAÑOLA
#
#   Country Of Birth  Born Date                Housing Type     Labor Situation  \
# 0            SPAIN 1959-09-02    2 - PROPIEDAD HIPOTECADA      03 FUNCIONARIO
# 1            SPAIN 1971-04-15       4 - FAMILIARES/PADRES           06 PARADO
# 2            SPAIN 1968-02-10  1 - PROPIEDAD SIN HIPOTECA  01 ASALARIADO FIJO
# 3            SPAIN 1968-12-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
# 4            SPAIN 1977-02-22    2 - PROPIEDAD HIPOTECADA         04 AUTONOMO
#
#             Marital Status  Income Amount  Number Pay Price List  \
# 0               2 - CASADO           2000          13      EED
# 1  4 - SEPARADO/DIVORCIADO            600          12      EED
# 2  4 - SEPARADO/DIVORCIADO           2500          14      HBD
# 3               2 - CASADO           1800          12      EED
# 4               2 - CASADO           1500          12      EEE
#
#    Account Balance Monitoring Status Date  Monitoring Status  Precio Contado  \
# 0              0.0             2019-06-30                  1             435
# 1              0.0             2015-01-05                  0             494
# 2              0.0             2015-01-05                  0             554
# 3              0.0             2015-01-13                  0             494
# 4              0.0             2015-01-07                  0             554
#
#    Precio Financiado  Quejas
# 0              360.0       0
# 1              360.0      12
# 2                0.0       0
# 3                0.0       2
# 4              360.0       0

# %% [markdown]
# ### Filtrado de una comunidad para MVP

# %%
provincias = ['Alicante', 'Valencia', 'Castellon']

data_filtered = data[data['Provincia'].isin(provincias)]
data_filtered.head()
# Out:
#    Installation Date Installation Number  Client Type    Panel Territorial  \
# 21        2015-01-12             1835558  Normal       SDVFAST        Este
# 33        2015-01-12             1835654  Normal       SDVFAST        Este
# 43        2015-01-12             1835683  Normal       SDVFAST        Este
# 48        2015-01-12             1835716  Normal       SDVFAST        Este
# 51        2015-01-12             1835728  Normal       SDVFAST        Este
#
#    Provincia    Zip      Gender    Nationality Country Of Birth  Born Date  \
# 21  Valencia  46900  H - HOMBRE  ES - ESPAÑOLA            SPAIN 1972-01-02
# 33  Valencia  46716  H - HOMBRE  ES - ESPAÑOLA            SPAIN 1989-09-20
# 43  Valencia  46716  H - HOMBRE  ES - ESPAÑOLA            SPAIN 1963-05-31
# 48  Alicante  03110  H - HOMBRE  ES - ESPAÑOLA            SPAIN 1958-07-31
# 51  Valencia  46394  H - HOMBRE  ES - ESPAÑOLA            SPAIN 1975-04-08
#
#                   Housing Type     Labor Situation           Marital Status  \
# 21  1 - PROPIEDAD SIN HIPOTECA         04 AUTONOMO               2 - CASADO
# 33  1 - PROPIEDAD SIN HIPOTECA  01 ASALARIADO FIJO              1 - SOLTERO
# 43  1 - PROPIEDAD SIN HIPOTECA  01 ASALARIADO FIJO               2 - CASADO
# 48    2 - PROPIEDAD HIPOTECADA      03 FUNCIONARIO  4 - SEPARADO/DIVORCIADO
# 51  1 - PROPIEDAD SIN HIPOTECA         04 AUTONOMO               2 - CASADO
#
#     Income Amount  Number Pay Price List  Account Balance  \
# 21           2009          12      HBE                0.0
# 33           1500          12      EED                0.0
# 43           2000          12      EED                0.0
# 48           1400          12      HBD                0.0
# 51           2000          12      HBE                0.0
#
#    Monitoring Status Date  Monitoring Status  Precio Contado  \
# 21             2015-01-14                  0             435
# 33             2015-01-13                  0             494
# 43             2015-01-13                  0             494
# 48             2020-01-31                  1             554
# 51             2015-01-13                  0             435
#
#     Precio Financiado  Quejas
# 21              360.0       0
# 33              360.0       0
# 43                0.0       0
# 48                0.0       1
# 51              360.0       1

# %%
data_filtered.to_excel('../data/portfolio_com_valencia.xlsx')
