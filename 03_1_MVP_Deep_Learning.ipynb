# %% [markdown]
# <a href="https://colab.research.google.com/github/albertodiazr/TFM_churn/blob/main/03_1_MVP_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modelo MVP con Deep Learning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import datetime as dt
from datetime import datetime
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve, plot_precision_recall_curve
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, roc_curve, average_precision_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler

# Using Activo and Baja for 0 and 1 (confusion matrix)   
class_names = ['Activo','Baja']

pd.options.display.max_columns = None

# %matplotlib inline

# %%
data = pd.read_excel('/content/drive/MyDrive/TFM_Churn/data/portfolio_com_valencia.xlsx')
data['Cliente'] = data['Cliente'].astype('str')
data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes
# 0       1            0       441.63
# 1       0            0       152.57
# 2       1            0       288.73
# 3       1            0       103.97
# 4       0            8       145.43

# %%
data['Born Date'].isnull().sum()
# Out:
# 226

# %%
data['Born Date'] = data['Born Date'].replace(np.nan, datetime(1970, 1, 1))

data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes
# 0       1            0       441.63
# 1       0            0       152.57
# 2       1            0       288.73
# 3       1            0       103.97
# 4       0            8       145.43

# %%
data['Born Date'].isnull().sum()
# Out:
# 0

# %%
# Edad en el momento del alta

data['Edad'] = ((data['Fecha Alta'] - data['Born Date']).dt.days)/365
                        
data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes       Edad
# 0       1            0       441.63  40.649315
# 1       0            0       152.57  37.676712
# 2       1            0       288.73  31.821918
# 3       1            0       103.97  37.939726
# 4       0            8       145.43  24.438356

# %%
plt.hist(data['Edad'], range = (-100,0));

# %%
plt.hist(data['Edad'], range = (0,18));

# %%
edad_mean = data['Edad'].mean()
edad_mean
# Out:
# 49.411166614701536

# %%
data['Edad'] = data['Edad'].apply(lambda x: edad_mean if x<18 else x)

# %%
plt.hist(data['Edad']);

# %%
# Mapping Edad 
data.loc[data['Edad'] <= 30, 'Rango_Edad'] = "18-30"
data.loc[(data['Edad'] > 30) & (data['Edad'] <= 40), 'Rango_Edad'] = "30-40"
data.loc[(data['Edad'] > 40) & (data['Edad'] <= 50), 'Rango_Edad'] = "40-50"
data.loc[(data['Edad'] > 50) & (data['Edad'] <= 60), 'Rango_Edad'] = "50-60"
data.loc[(data['Edad'] > 60) & (data['Edad'] <= 70), 'Rango_Edad'] = "60-70"
data.loc[(data['Edad'] > 70) & (data['Edad'] <= 80), 'Rango_Edad'] = "70-80"
data.loc[data['Edad'] > 80, 'Rango_Edad'] = "+80"
data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes       Edad Rango_Edad
# 0       1            0       441.63  40.649315      40-50
# 1       0            0       152.57  37.676712      30-40
# 2       1            0       288.73  31.821918      30-40
# 3       1            0       103.97  37.939726      30-40
# 4       0            8       145.43  24.438356      18-30

# %%
tab1 = pd.crosstab(data["Rango_Edad"], data["Estado"], margins = True)
tab2 = pd.crosstab(data["Rango_Edad"], data["Estado"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Estado          0      1    All         0         1
# Rango_Edad
# +80           961    203   1164  0.825601  0.174399
# 18-30        2584   2258   4842  0.533664  0.466336
# 30-40        6163   3749   9912  0.621772  0.378228
# 40-50       10346   3941  14287  0.724155  0.275845
# 50-60        9324   2274  11598  0.803932  0.196068
# 60-70        7571   1276   8847  0.855770  0.144230
# 70-80        3988    589   4577  0.871313  0.128687
# All         40937  14290  55227  0.741250  0.258750

# %%
plt.hist(data['Ingresos'], range=(0, 5000));

# %%
data.loc[data['Ingresos'] <= 1000, 'Income'] = "0-1000"
data.loc[(data['Ingresos'] > 1000) & (data['Ingresos'] <= 1500), 'Income'] = "1000-1500"
data.loc[(data['Ingresos'] > 1500) & (data['Ingresos'] <= 2000), 'Income'] = "1500-2000"
data.loc[(data['Ingresos'] > 2000) & (data['Ingresos'] <= 3000), 'Income'] = "2000-3000"
data.loc[data['Ingresos'] > 3000, 'Income'] = "+3000"
data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes       Edad Rango_Edad     Income
# 0       1            0       441.63  40.649315      40-50  2000-3000
# 1       0            0       152.57  37.676712      30-40  1000-1500
# 2       1            0       288.73  31.821918      30-40     0-1000
# 3       1            0       103.97  37.939726      30-40  1000-1500
# 4       0            8       145.43  24.438356      18-30     0-1000

# %%
tab1 = pd.crosstab(data["Income"], data["Estado"], margins = True)
tab2 = pd.crosstab(data["Income"], data["Estado"], margins = True, normalize = 'index')
pd.concat([tab1, tab2], axis = 1)
# Out:
# Estado         0      1    All         0         1
# Income
# +3000       1687    448   2135  0.790164  0.209836
# 0-1000      6979   3147  10126  0.689216  0.310784
# 1000-1500  18436   6408  24844  0.742071  0.257929
# 1500-2000   9482   3084  12566  0.754576  0.245424
# 2000-3000   4353   1203   5556  0.783477  0.216523
# All        40937  14290  55227  0.741250  0.258750

# %%
scaler = MinMaxScaler()
data['Quejas_sca'] = scaler.fit_transform(data['Quejas'].values.reshape(-1, 1))
data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes       Edad Rango_Edad     Income  \
# 0       1            0       441.63  40.649315      40-50  2000-3000
# 1       0            0       152.57  37.676712      30-40  1000-1500
# 2       1            0       288.73  31.821918      30-40     0-1000
# 3       1            0       103.97  37.939726      30-40  1000-1500
# 4       0            8       145.43  24.438356      18-30     0-1000
#
#    Quejas_sca
# 0    0.035714
# 1    0.000000
# 2    0.035714
# 3    0.035714
# 4    0.000000

# %%
plt.hist(data['Quejas_sca']);

# %%
scaler = MinMaxScaler()
data['Incidencias_sca'] = scaler.fit_transform(data['Incidencias'].values.reshape(-1, 1))
data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes       Edad Rango_Edad     Income  \
# 0       1            0       441.63  40.649315      40-50  2000-3000
# 1       0            0       152.57  37.676712      30-40  1000-1500
# 2       1            0       288.73  31.821918      30-40     0-1000
# 3       1            0       103.97  37.939726      30-40  1000-1500
# 4       0            8       145.43  24.438356      18-30     0-1000
#
#    Quejas_sca  Incidencias_sca
# 0    0.035714         0.000000
# 1    0.000000         0.000000
# 2    0.035714         0.000000
# 3    0.035714         0.000000
# 4    0.000000         0.470588

# %%
plt.hist(data['Incidencias_sca']);

# %%
scaler = MinMaxScaler()
data['Consumo_sca'] = scaler.fit_transform(data['Consumo Mes'].values.reshape(-1, 1))
data.head()
# Out:
#   Fecha Alta Cliente Modelo Caldera Provincia  Gender    Pais  Born Date  \
# 0 2014-01-01      17         Biasi   Alicante  Hombre  España 1973-05-19
# 1 2014-01-01      54         Biasi   Alicante  Hombre  España 1976-05-08
# 2 2014-01-01      84         Biasi   Valencia  Hombre  España 1982-03-15
# 3 2014-01-01     103         Biasi   Alicante  Hombre  España 1976-02-02
# 4 2014-01-01     110         Biasi   Alicante   Mujer  España 1989-07-31
#
#     Tipo Propiedad Situacion Laboral Estado Civil  Ingresos  Pagos Anuales  \
# 0  Propiedad Total          Autonomo       Casado      2500             14
# 1  Propiedad Total            Parado      Soltero      1200             14
# 2  Propiedad Total  Trabajo Temporal      Soltero       800             14
# 3  Propiedad Total          Autonomo       Casado      1500             12
# 4  Propiedad Total            Parado      Soltero      1000             12
#
#   Fecha Estado  Estado Tipo Inmueble  Financiado Precio Contado  Precio Total  \
# 0   2016-09-14       1          Casa  Financiado    Promo 0 EUR           399
# 1   2016-12-29       1          Piso  Financiado    Promo 0 EUR           399
# 2   2017-02-24       1          Casa  Financiado    0 - 100 EUR           399
# 3   2014-01-01       0          Casa  Financiado    Promo 0 EUR           399
# 4   2017-03-11       1          Piso  Financiado    Promo 0 EUR           399
#
#    Quejas  Incidencias  Consumo Mes       Edad Rango_Edad     Income  \
# 0       1            0       441.63  40.649315      40-50  2000-3000
# 1       0            0       152.57  37.676712      30-40  1000-1500
# 2       1            0       288.73  31.821918      30-40     0-1000
# 3       1            0       103.97  37.939726      30-40  1000-1500
# 4       0            8       145.43  24.438356      18-30     0-1000
#
#    Quejas_sca  Incidencias_sca  Consumo_sca
# 0    0.035714         0.000000     0.385207
# 1    0.000000         0.000000     0.133043
# 2    0.035714         0.000000     0.251823
# 3    0.035714         0.000000     0.090647
# 4    0.000000         0.470588     0.126815

# %%
plt.hist(data['Consumo_sca']);

# %%
data_filtered = data[['Gender', 'Tipo Inmueble', 'Tipo Propiedad', 'Situacion Laboral', 'Estado Civil', 
                      'Provincia', 'Pais', 'Rango_Edad', 'Income', 'Precio Contado', 'Pagos Anuales', 'Precio Total',
                      'Quejas_sca', 'Incidencias_sca', 'Consumo_sca', 'Estado']]
data_filtered.columns
# Out:
# Index(['Gender', 'Tipo Inmueble', 'Tipo Propiedad', 'Situacion Laboral',
#        'Estado Civil', 'Provincia', 'Pais', 'Rango_Edad', 'Income',
#        'Precio Contado', 'Pagos Anuales', 'Precio Total', 'Quejas_sca',
#        'Incidencias_sca', 'Consumo_sca', 'Estado'],
#       dtype='object')

# %%
X = data_filtered.drop(['Estado'],axis=1)
y = data_filtered['Estado']

# %%
from sklearn.model_selection import train_test_split
X_train_prev, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0, stratify = y)

# %%
features_TE = ['Gender', 'Tipo Inmueble', 'Tipo Propiedad', 'Situacion Laboral', 'Estado Civil', 'Precio Total',
               'Provincia', 'Pais', 'Rango_Edad', 'Income', 'Precio Contado', 'Pagos Anuales']

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.2.2-py2.py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 6.7 MB/s
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2

# %%
from category_encoders import TargetEncoder

TE_encoder = TargetEncoder(cols=features_TE)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
X_train_prev.head()
# Out:
#        Gender Tipo Inmueble   Tipo Propiedad Situacion Laboral Estado Civil  \
# 25918  Hombre          Casa  Propiedad Total          Jubilado       Casado
# 5305   Hombre          Piso          Empresa          Autonomo       Casado
# 38504  Hombre          Casa  Propiedad Total      Trabajo Fijo       Casado
# 35496  Hombre          Piso  Propiedad Total          Jubilado        Viudo
# 8046   Hombre          Piso  Propiedad Total          Autonomo       Casado
#
#       Provincia           Pais Rango_Edad     Income Precio Contado  \
# 25918  Alicante         España      60-70     0-1000    0 - 100 EUR
# 5305   Alicante         España      40-50  1000-1500    0 - 100 EUR
# 38504  Alicante  Union Europea      40-50  1500-2000    0 - 100 EUR
# 35496  Alicante         España        +80  1000-1500  100 - 200 EUR
# 8046   Valencia         España      60-70  1000-1500  100 - 200 EUR
#
#        Pagos Anuales  Precio Total  Quejas_sca  Incidencias_sca  Consumo_sca
# 25918             12           399    0.035714         0.000000     0.234751
# 5305              14           399    0.000000         0.000000     0.059634
# 38504             14           399    0.000000         0.000000     0.299881
# 35496             12           499    0.000000         0.000000     0.061728
# 8046              14           499    0.000000         0.117647     0.081836

# %%
TE_encoder.fit(X_train_prev, y_train)
X_train = TE_encoder.transform(X_train_prev)
X_train.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#        Gender  Tipo Inmueble  Tipo Propiedad  Situacion Laboral  Estado Civil  \
# 25918  0.2536       0.207625        0.229333           0.144286      0.219828
# 5305   0.2536       0.210947        0.272727           0.337908      0.219828
# 38504  0.2536       0.207625        0.229333           0.219986      0.219828
# 35496  0.2536       0.210947        0.229333           0.144286      0.183570
# 8046   0.2536       0.210947        0.229333           0.337908      0.219828
#
#        Provincia      Pais  Rango_Edad    Income  Precio Contado  \
# 25918   0.220812  0.254659    0.145050  0.311213        0.326792
# 5305    0.220812  0.254659    0.277612  0.257715        0.326792
# 38504   0.220812  0.250320    0.277612  0.244343        0.326792
# 35496   0.220812  0.254659    0.163866  0.257715        0.237826
# 8046    0.272935  0.254659    0.145050  0.257715        0.237826
#
#        Pagos Anuales  Precio Total  Quejas_sca  Incidencias_sca  Consumo_sca
# 25918       0.282987      0.312914    0.035714         0.000000     0.234751
# 5305        0.234842      0.312914    0.000000         0.000000     0.059634
# 38504       0.234842      0.312914    0.000000         0.000000     0.299881
# 35496       0.282987      0.250299    0.000000         0.000000     0.061728
# 8046        0.234842      0.250299    0.000000         0.117647     0.081836

# %%
X_test = TE_encoder.transform(X_test)
X_test.head()
# Out:
#          Gender  Tipo Inmueble  Tipo Propiedad  Situacion Laboral  \
# 15591  0.253600       0.210947        0.229333           0.337908
# 27726  0.278034       0.210947        0.229333           0.337908
# 16792  0.253600       0.207625        0.229333           0.460733
# 23233  0.253600       0.210947        0.229333           0.337908
# 24836  0.253600       0.207625        0.229333           0.219986
#
#        Estado Civil  Provincia      Pais  Rango_Edad    Income  \
# 15591      0.370321   0.272935  0.254659    0.196224  0.244343
# 27726      0.370321   0.272935  0.254659    0.378727  0.257715
# 16792      0.219828   0.220812  0.254659    0.196224  0.257715
# 23233      0.219828   0.343207  0.254659    0.378727  0.257715
# 24836      0.219828   0.343207  0.254659    0.378727  0.244343
#
#        Precio Contado  Pagos Anuales  Precio Total  Quejas_sca  \
# 15591        0.326792       0.282987      0.312914    0.000000
# 27726        0.185057       0.234842      0.195478    0.000000
# 16792        0.326792       0.234842      0.312914    0.000000
# 23233        0.308267       0.234842      0.312914    0.035714
# 24836        0.237826       0.234842      0.250299    0.000000
#
#        Incidencias_sca  Consumo_sca
# 15591         0.000000     0.107919
# 27726         0.000000     0.021408
# 16792         0.000000     0.210002
# 23233         0.411765     0.042248
# 24836         0.000000     0.280463

# %% [markdown]
# ## Deep Learning

# %%
import tensorflow as tf
from tensorflow import keras
from keras import models, layers, losses, metrics, optimizers

# %%
model = models.Sequential()

model.add(layers.Dense(100, input_dim=15, activation = 'tanh'))
model.add(layers.Dense(300, activation = 'tanh'))
model.add(layers.Dense(300, activation = 'tanh'))
model.add(layers.Dense(1, activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 100)               1600
# _________________________________________________________________
# dense_29 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dense_30 (Dense)             (None, 300)               90300
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 301
# =================================================================
# Total params: 122,501
# Trainable params: 122,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = optimizers.SGD(lr = 0.01)
model.compile(loss = 'binary_crossentropy', optimizer = sgd, metrics=['accuracy'])
# model.compile(loss = 'binary_crossentropy', optimizer = sgd, metrics=[tf.keras.metrics.Recall(thresholds=0.5)])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
class_weight = {0: 1.,
                1: 3.}

# %%
h = model.fit(X_train, y_train, epochs = 100, batch_size = 4096, validation_split=.2, class_weight=class_weight)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 9/9 [==============================] - 1s 70ms/step - loss: 1.0659 - accuracy: 0.6879 - val_loss: 0.6964 - val_accuracy: 0.4246
# Epoch 2/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0610 - accuracy: 0.3559 - val_loss: 0.7058 - val_accuracy: 0.2758
# Epoch 3/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0568 - accuracy: 0.2629 - val_loss: 0.7108 - val_accuracy: 0.2609
# Epoch 4/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0550 - accuracy: 0.2545 - val_loss: 0.7143 - val_accuracy: 0.2604
# Epoch 5/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0482 - accuracy: 0.2521 - val_loss: 0.7157 - val_accuracy: 0.2645
# Epoch 6/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0532 - accuracy: 0.2605 - val_loss: 0.7148 - val_accuracy: 0.2652
# Epoch 7/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0525 - accuracy: 0.2615 - val_loss: 0.7144 - val_accuracy: 0.2664
# Epoch 8/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0501 - accuracy: 0.2611 - val_loss: 0.7127 - val_accuracy: 0.2659
# Epoch 9/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0471 - accuracy: 0.2594 - val_loss: 0.7123 - val_accuracy: 0.2649
# Epoch 10/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0470 - accuracy: 0.2596 - val_loss: 0.7110 - val_accuracy: 0.2641
# Epoch 11/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0445 - accuracy: 0.2581 - val_loss: 0.7102 - val_accuracy: 0.2638
# Epoch 12/100
# 9/9 [==============================] - 0s 9ms/step - loss: 1.0401 - accuracy: 0.2554 - val_loss: 0.7098 - val_accuracy: 0.2637
# Epoch 13/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0414 - accuracy: 0.2576 - val_loss: 0.7085 - val_accuracy: 0.2637
# Epoch 14/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0413 - accuracy: 0.2588 - val_loss: 0.7073 - val_accuracy: 0.2637
# Epoch 15/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0386 - accuracy: 0.2578 - val_loss: 0.7064 - val_accuracy: 0.2637
# Epoch 16/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0351 - accuracy: 0.2560 - val_loss: 0.7061 - val_accuracy: 0.2637
# Epoch 17/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0364 - accuracy: 0.2579 - val_loss: 0.7049 - val_accuracy: 0.2638
# Epoch 18/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0359 - accuracy: 0.2594 - val_loss: 0.7030 - val_accuracy: 0.2688
# Epoch 19/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0314 - accuracy: 0.2655 - val_loss: 0.7023 - val_accuracy: 0.2766
# Epoch 20/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0290 - accuracy: 0.2788 - val_loss: 0.7023 - val_accuracy: 0.2819
# Epoch 21/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0313 - accuracy: 0.2843 - val_loss: 0.7015 - val_accuracy: 0.3034
# Epoch 22/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0256 - accuracy: 0.3125 - val_loss: 0.7011 - val_accuracy: 0.3206
# Epoch 23/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0272 - accuracy: 0.3223 - val_loss: 0.6991 - val_accuracy: 0.3622
# Epoch 24/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0274 - accuracy: 0.3629 - val_loss: 0.6980 - val_accuracy: 0.3959
# Epoch 25/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0240 - accuracy: 0.4019 - val_loss: 0.6971 - val_accuracy: 0.4240
# Epoch 26/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0252 - accuracy: 0.4239 - val_loss: 0.6955 - val_accuracy: 0.4615
# Epoch 27/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0218 - accuracy: 0.4612 - val_loss: 0.6946 - val_accuracy: 0.4806
# Epoch 28/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0177 - accuracy: 0.4921 - val_loss: 0.6941 - val_accuracy: 0.4953
# Epoch 29/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0224 - accuracy: 0.4875 - val_loss: 0.6931 - val_accuracy: 0.5147
# Epoch 30/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0193 - accuracy: 0.5095 - val_loss: 0.6918 - val_accuracy: 0.5371
# Epoch 31/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0167 - accuracy: 0.5364 - val_loss: 0.6909 - val_accuracy: 0.5504
# Epoch 32/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0182 - accuracy: 0.5435 - val_loss: 0.6897 - val_accuracy: 0.5670
# Epoch 33/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0109 - accuracy: 0.5681 - val_loss: 0.6893 - val_accuracy: 0.5690
# Epoch 34/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0119 - accuracy: 0.5697 - val_loss: 0.6886 - val_accuracy: 0.5770
# Epoch 35/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0108 - accuracy: 0.5773 - val_loss: 0.6880 - val_accuracy: 0.5845
# Epoch 36/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0124 - accuracy: 0.5776 - val_loss: 0.6864 - val_accuracy: 0.5982
# Epoch 37/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0078 - accuracy: 0.5948 - val_loss: 0.6861 - val_accuracy: 0.5991
# Epoch 38/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0086 - accuracy: 0.5958 - val_loss: 0.6851 - val_accuracy: 0.6063
# Epoch 39/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0061 - accuracy: 0.6019 - val_loss: 0.6845 - val_accuracy: 0.6105
# Epoch 40/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0018 - accuracy: 0.6112 - val_loss: 0.6839 - val_accuracy: 0.6133
# Epoch 41/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0028 - accuracy: 0.6120 - val_loss: 0.6822 - val_accuracy: 0.6237
# Epoch 42/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0065 - accuracy: 0.6169 - val_loss: 0.6806 - val_accuracy: 0.6348
# Epoch 43/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1.0014 - accuracy: 0.6285 - val_loss: 0.6796 - val_accuracy: 0.6387
# Epoch 44/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0014 - accuracy: 0.6339 - val_loss: 0.6784 - val_accuracy: 0.6444
# Epoch 45/100
# 9/9 [==============================] - 0s 9ms/step - loss: 1.0009 - accuracy: 0.6376 - val_loss: 0.6777 - val_accuracy: 0.6443
# Epoch 46/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9972 - accuracy: 0.6420 - val_loss: 0.6768 - val_accuracy: 0.6475
# Epoch 47/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9986 - accuracy: 0.6398 - val_loss: 0.6753 - val_accuracy: 0.6555
# Epoch 48/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9941 - accuracy: 0.6474 - val_loss: 0.6748 - val_accuracy: 0.6555
# Epoch 49/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9965 - accuracy: 0.6445 - val_loss: 0.6735 - val_accuracy: 0.6602
# Epoch 50/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9927 - accuracy: 0.6498 - val_loss: 0.6727 - val_accuracy: 0.6620
# Epoch 51/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9924 - accuracy: 0.6512 - val_loss: 0.6716 - val_accuracy: 0.6644
# Epoch 52/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9899 - accuracy: 0.6588 - val_loss: 0.6699 - val_accuracy: 0.6698
# Epoch 53/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9914 - accuracy: 0.6582 - val_loss: 0.6688 - val_accuracy: 0.6719
# Epoch 54/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9866 - accuracy: 0.6655 - val_loss: 0.6691 - val_accuracy: 0.6683
# Epoch 55/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9871 - accuracy: 0.6582 - val_loss: 0.6682 - val_accuracy: 0.6700
# Epoch 56/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9829 - accuracy: 0.6653 - val_loss: 0.6677 - val_accuracy: 0.6699
# Epoch 57/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9836 - accuracy: 0.6638 - val_loss: 0.6661 - val_accuracy: 0.6751
# Epoch 58/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9812 - accuracy: 0.6669 - val_loss: 0.6654 - val_accuracy: 0.6748
# Epoch 59/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9845 - accuracy: 0.6632 - val_loss: 0.6635 - val_accuracy: 0.6785
# Epoch 60/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9793 - accuracy: 0.6690 - val_loss: 0.6622 - val_accuracy: 0.6803
# Epoch 61/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9749 - accuracy: 0.6763 - val_loss: 0.6628 - val_accuracy: 0.6774
# Epoch 62/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9795 - accuracy: 0.6662 - val_loss: 0.6603 - val_accuracy: 0.6828
# Epoch 63/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9747 - accuracy: 0.6762 - val_loss: 0.6602 - val_accuracy: 0.6811
# Epoch 64/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9714 - accuracy: 0.6764 - val_loss: 0.6604 - val_accuracy: 0.6789
# Epoch 65/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9727 - accuracy: 0.6702 - val_loss: 0.6591 - val_accuracy: 0.6813
# Epoch 66/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9742 - accuracy: 0.6705 - val_loss: 0.6571 - val_accuracy: 0.6834
# Epoch 67/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9676 - accuracy: 0.6806 - val_loss: 0.6561 - val_accuracy: 0.6841
# Epoch 68/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9666 - accuracy: 0.6823 - val_loss: 0.6562 - val_accuracy: 0.6829
# Epoch 69/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9716 - accuracy: 0.6767 - val_loss: 0.6534 - val_accuracy: 0.6881
# Epoch 70/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9656 - accuracy: 0.6820 - val_loss: 0.6535 - val_accuracy: 0.6856
# Epoch 71/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9644 - accuracy: 0.6811 - val_loss: 0.6528 - val_accuracy: 0.6864
# Epoch 72/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9656 - accuracy: 0.6811 - val_loss: 0.6505 - val_accuracy: 0.6891
# Epoch 73/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9619 - accuracy: 0.6861 - val_loss: 0.6503 - val_accuracy: 0.6886
# Epoch 74/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9611 - accuracy: 0.6854 - val_loss: 0.6487 - val_accuracy: 0.6904
# Epoch 75/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9600 - accuracy: 0.6848 - val_loss: 0.6479 - val_accuracy: 0.6905
# Epoch 76/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9611 - accuracy: 0.6813 - val_loss: 0.6464 - val_accuracy: 0.6931
# Epoch 77/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9620 - accuracy: 0.6861 - val_loss: 0.6449 - val_accuracy: 0.6959
# Epoch 78/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9593 - accuracy: 0.6865 - val_loss: 0.6448 - val_accuracy: 0.6939
# Epoch 79/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9562 - accuracy: 0.6893 - val_loss: 0.6441 - val_accuracy: 0.6939
# Epoch 80/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9553 - accuracy: 0.6879 - val_loss: 0.6434 - val_accuracy: 0.6933
# Epoch 81/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9548 - accuracy: 0.6853 - val_loss: 0.6417 - val_accuracy: 0.6965
# Epoch 82/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9541 - accuracy: 0.6892 - val_loss: 0.6408 - val_accuracy: 0.6966
# Epoch 83/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9514 - accuracy: 0.6898 - val_loss: 0.6410 - val_accuracy: 0.6950
# Epoch 84/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9485 - accuracy: 0.6888 - val_loss: 0.6407 - val_accuracy: 0.6942
# Epoch 85/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9502 - accuracy: 0.6878 - val_loss: 0.6384 - val_accuracy: 0.6968
# Epoch 86/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9468 - accuracy: 0.6917 - val_loss: 0.6387 - val_accuracy: 0.6956
# Epoch 87/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9450 - accuracy: 0.6895 - val_loss: 0.6381 - val_accuracy: 0.6955
# Epoch 88/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9417 - accuracy: 0.6909 - val_loss: 0.6368 - val_accuracy: 0.6967
# Epoch 89/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9424 - accuracy: 0.6926 - val_loss: 0.6363 - val_accuracy: 0.6965
# Epoch 90/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9480 - accuracy: 0.6856 - val_loss: 0.6329 - val_accuracy: 0.7008
# Epoch 91/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9433 - accuracy: 0.6938 - val_loss: 0.6334 - val_accuracy: 0.6985
# Epoch 92/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9422 - accuracy: 0.6918 - val_loss: 0.6313 - val_accuracy: 0.7014
# Epoch 93/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9364 - accuracy: 0.6991 - val_loss: 0.6319 - val_accuracy: 0.6984
# Epoch 94/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9403 - accuracy: 0.6907 - val_loss: 0.6319 - val_accuracy: 0.6982
# Epoch 95/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9373 - accuracy: 0.6930 - val_loss: 0.6306 - val_accuracy: 0.6989
# Epoch 96/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9386 - accuracy: 0.6924 - val_loss: 0.6311 - val_accuracy: 0.6972
# Epoch 97/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9327 - accuracy: 0.6944 - val_loss: 0.6304 - val_accuracy: 0.6973
# Epoch 98/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9330 - accuracy: 0.6933 - val_loss: 0.6309 - val_accuracy: 0.6957
# Epoch 99/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9319 - accuracy: 0.6927 - val_loss: 0.6287 - val_accuracy: 0.6989
# Epoch 100/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9350 - accuracy: 0.6910 - val_loss: 0.6263 - val_accuracy: 0.7015

# %%
def plot_history(history, metric):

  d = history.history
  epochs = range(1, len(d[metric]) + 1)

  plt.plot(epochs, d[metric])

  if 'val_' + metric in d:
    plt.plot(epochs, d['val_' + metric])

# %%
plot_history(h, 'loss')

# %%
y_pred = model.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
# rounded = [int(round(x[0])) for x in y_pred]
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [1]], dtype=int32)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
   
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
              
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.70      0.78      8188
#            1       0.45      0.69      0.54      2858
#
#     accuracy                           0.70     11046
#    macro avg       0.66      0.70      0.66     11046
# weighted avg       0.76      0.70      0.72     11046

# %%
class_names = ['Activo','Baja']
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm, classes=class_names, title='Confusion matrix')
